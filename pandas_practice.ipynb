# %%
import pandas as pd

# A DataFrame is just a table — like Excel
data = {
    'name': ['Alice', 'Bob', 'Charlie', 'Diana'],
    'city': ['Mumbai', 'Delhi', 'Mumbai', 'Chennai'],
    'sales': [5000, 3000, 7000, 4000]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       name     city  sales
# 0    Alice   Mumbai   5000
# 1      Bob    Delhi   3000
# 2  Charlie   Mumbai   7000
# 3    Diana  Chennai   4000

# %%
print(df['sales'])
# Out:
# 0    5000
# 1    3000
# 2    7000
# 3    4000
# Name: sales, dtype: int64

# %%
print(df[sales].max)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(df[sales].max)
#
# NameError: name 'sales' is not defined

# %%
print(df['sales'].max)
# Out:
# <bound method Series.max of 0    5000
# 1    3000
# 2    7000
# 3    4000
# Name: sales, dtype: int64>

# %%
print(df['sales'].max())
# Out:
# 7000

# %%
yes = df[df['city' = 'mumbai']] 
print(yes)
# Out:
#   Cell In[6], line 1
#     yes = df[df['city' = 'mumbai']]
#                 ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
yes = df[df['city' == 'mumbai']] 
print(yes)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
# --> 167 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
# --> 196 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7088 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
yes = df[df['city'] == 'mumbai']
print(yes)
# Out:
# Empty DataFrame
# Columns: [name, city, sales]
# Index: []

# %%
yes = df[df['city'] == 'Mumbai']
print(yes)
# Out:
#       name    city  sales
# 0    Alice  Mumbai   5000
# 2  Charlie  Mumbai   7000

# %%
SALES_ABOVE_4000 = DF[DF['SALES'] > '4000' ] 
print(SALES_ABOVE_4000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 SALES_ABOVE_4000 = DF[DF['SALES'] > '4000' ]
#       2 print(SALES_ABOVE_4000)
#
# NameError: name 'DF' is not defined

# %%
SALES_ABOVE_4000 = df[df['SALES'] > '4000' ] 
print(SALES_ABOVE_4000)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
# --> 167 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
# --> 196 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7088 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
SALES_ABOVE_4000 = DF[DF['sales'] > '4000' ] 
print(SALES_ABOVE_4000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 SALES_ABOVE_4000 = DF[DF['sales'] > '4000' ]
#       2 print(SALES_ABOVE_4000)
#
# NameError: name 'DF' is not defined

# %%
SALES_ABOVE_4000 = df[df['sales'] > '4000' ] 
print(SALES_ABOVE_4000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 SALES_ABOVE_4000 = df[df['sales'] > '4000' ]
#       2 print(SALES_ABOVE_4000)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\series.py:6138, in Series._cmp_method(self, other, op)
#    6135 lvalues = self._values
# ...

# %%
SALES_ABOVE_4000 = df[df['sales'] > 4000] 
print(SALES_ABOVE_4000)
# Out:
#       name    city  sales
# 0    Alice  Mumbai   5000
# 2  Charlie  Mumbai   7000

# %%
city_wide_sales = df.groupby('city')['sales'].sum()
print(city_wide_sales)
# Out:
# city
# Chennai     4000
# Delhi       3000
# Mumbai     12000
# Name: sales, dtype: int64
